# %% [markdown]
# <a href="https://colab.research.google.com/github/MoralesCMaJo/Tarea-2--An-lisis-de-series-temporales/blob/main/1_introduction_to_time_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Primero instalar
# !pip install pandas yfinance matplotlib numpy
#Luego importar
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
#import seaborn as sns
#sns.set()

# %%
#Importar la base de datos
from google.colab import drive
drive.mount('/content/drive')

import shutil

# Ruta del archivo en Google Drive
ruta_drive = "/content/drive/My Drive/Index_2023.csv"

# Ruta de destino en Google Colab
ruta_colab = "/content/Index_2023.csv"
# Out:
# Mounted at /content/drive

# %%
#Mostrará las primeras 5 filas del DataFrame.
df_comp.head()
# Out:
#         Date         spx          dax         ftse        nikkei
#
# 0 1994-01-07  469.899994  2224.949951  3446.000000  18124.009766
# 1 1994-01-10  475.269989  2225.000000  3440.600098  18443.439453
# 2 1994-01-11  474.130005  2228.100098  3413.800049  18485.250000
# 3 1994-01-12  474.170013  2182.060059  3372.000000  18793.880859
# 4 1994-01-13  472.470001  2142.370117  3360.000000  18577.259766

# %%
df_comp
# Out:
#            Date          spx           dax         ftse        nikkei
#
# 0    1994-01-07   469.899994   2224.949951  3446.000000  18124.009766
# 1    1994-01-10   475.269989   2225.000000  3440.600098  18443.439453
# 2    1994-01-11   474.130005   2228.100098  3413.800049  18485.250000
# 3    1994-01-12   474.170013   2182.060059  3372.000000  18793.880859
# 4    1994-01-13   472.470001   2142.370117  3360.000000  18577.259766
# ...         ...          ...           ...          ...           ...
# 7746 2023-09-18  4453.529785  15727.120117  7652.899902  33533.089844
# 7747 2023-09-19  4443.950195  15664.480469  7660.200195  33242.589844
# 7748 2023-09-20  4402.200195  15781.589844  7731.700195  33023.781250
# 7749 2023-09-21  4330.000000  15571.860352  7678.600098  32571.029297
# 7750 2023-09-22  4320.060059  15557.290039  7683.899902  32402.410156
#
# [7751 rows x 5 columns]

# %%
#se utiliza para generar un resumen estadístico de un DataFrame llamado df_comp
df_comp.describe()
# Out:
#                spx           dax         ftse        nikkei
#
# count  7751.000000   7751.000000  7751.000000   7751.000000
# mean   1720.123667   7489.715990  5746.746213  16627.295093
# std    1035.983879   3883.758116  1250.400017   5768.941477
# min     438.920013   1911.699951  2876.600098   7054.979980
# 25%    1084.670044   4494.935059  4903.149902  11356.860352
# 50%    1330.410034   6490.689941  5923.500000  16401.730469
# 75%    2104.189941  10664.784668  6694.200195  20211.270508
# max    4796.560059  16469.750000  8014.299805  33753.328125

# %%
# Sirve para verificar la existencia de valores faltantes
df_comp.isna()
# Out:
#        Date    spx    dax   ftse nikkei
#
# 0     False  False  False  False  False
# 1     False  False  False  False  False
# 2     False  False  False  False  False
# 3     False  False  False  False  False
# 4     False  False  False  False  False
# ...     ...    ...    ...    ...    ...
# 7746  False  False  False  False  False
# 7747  False  False  False  False  False
# 7748  False  False  False  False  False
# 7749  False  False  False  False  False
# 7750  False  False  False  False  False
#
# [7751 rows x 5 columns]

# %%
#Se observa que no hay valores faltantes
df_comp.spx.isna().sum()
# Out:
# 0

# %%
#creamos un gráfico de la columna "spx"(contiene los precios del índice S&P 500)
import matplotlib.pyplot as plt
df_comp.spx.plot(figsize=(20,5), title = "S&P500 Prices")
plt.show()

# %%
#creamos un gráfico de la columna "ftse" (que contiene los precios del índice FTSE 100)
df_comp.ftse.plot(figsize=(20,5), title = "FTSE100 Prices")
plt.show()

# %%
df_comp.spx.plot(figsize=(20,5), title = "S&P500 Prices")
df_comp.ftse.plot(figsize=(20,5), title = "FTSE100 Prices")
plt.title("S&P v FTSE")
plt.show()

# %%
#creamos un gráfico de probabilidad normal (Q-Q plot) de la columna "spx"
import scipy.stats
import pylab
scipy.stats.probplot(df_comp.spx, plot = pylab)
plt.title("QQ Plot", size = 24)
pylab.show()
